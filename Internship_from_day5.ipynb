# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferganamuthu-max/Data-Analytics-Using-Python-Project/blob/main/Internship_from_day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.Series([10,20,30,40])
print (data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = pd.Series([101,102,103],
index=["Gayathri","Jenifer","Priyanga"])
print(data)
# Out:
# Gayathri    101
# Jenifer     102
# Priyanga    103
# dtype: int64

# %%
import pandas as pd
employee = {
    "ID":[101,102,103,104],
    "Name":["Saranya","Nithya","Veni","Masila"],
    "Salary":[50000,25000,78000,62000]
}
df = pd.DataFrame(employee)
print(df)
# Out:
#     ID     Name  Salary
# 0  101  Saranya   50000
# 1  102   Nithya   25000
# 2  103     Veni   78000
# 3  104   Masila   62000

# %%
import numpy as np

#products
products = ["Fashion","Mobile","Tablet","Headphone","Smartwatch"]

#Sales units
sales = np.array([120,250,80,150,110])

#Total sales
print("Total Sales:",np.sum(sales))

#Average sales
print("Average Sales:",np.mean(sales))

#Highest sales
print("Highest Sales:",np.max(sales))

#Lowest sales
print("Lowest Sales:",np.min(sales))

#Best selling product
best_index = np.argmax(sales)
print("Best Selling Product:",products[best_index])

#product-wise sales
print("\nProduct Sales Report:")
for i in range(len(products)):
  print(products[i],":",sales[i])
# Out:
# Total Sales: 710
# Average Sales: 142.0
# Highest Sales: 250
# Lowest Sales: 80
# Best Selling Product: Mobile
#
# Product Sales Report:
# Fashion : 120
# Mobile : 250
# Tablet : 80
# Headphone : 150
# Smartwatch : 110
